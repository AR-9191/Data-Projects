# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/drake-lyrics/drake_data.csv
# /kaggle/input/drake-lyrics/drake_lyrics.txt
# /kaggle/input/drake-lyrics/drake_data.json

# %%
# this dataset contains all of drakes lyrics
df = pd.read_csv('/kaggle/input/drake-lyrics/drake_data.csv')

# %%
df.columns
# Out:
# Index(['album', 'lyrics_title', 'lyrics_url', 'lyrics', 'track_views'], dtype='object')

# %%
import re
spaces = r"\s+"
print(re.split(spaces, df["lyrics"][1]))
print(re.findall("me", df["lyrics"][1]))
# Out:
# ['[Verse]', 'Hands', 'are', 'tied', "Someone's", 'in', 'my', 'ear', 'from', 'the', 'other', 'side', "Tellin'", 'me', 'that', 'I', 'should', 'pay', 'you', 'no', 'mind', 'Wanted', 'you', 'to', 'not', 'be', 'with', 'me', 'all', 'night', 'Wanted', 'you', 'to', 'not', 'stay', 'with', 'me', 'all', 'night', 'I', 'know,', 'you', 'know,', 'who', 'that', 'person', 'is', 'to', 'me', "Doesn't", 'really', 'change', 'things', '[Chorus]', 'I', 'know', "you're", 'scared', 'of', 'dating,', 'falling', 'for', 'me', 'Shorty,', 'surely', 'you', 'know', 'me', 'Right', 'here', 'for', 'you', 'always', 'You', 'know,', 'I', "don't", 'ever', 'change', 'Right', 'here', 'for', 'you', 'always', 'You', 'know', 'I', "don't", 'ever', 'change', 'Right', 'here', 'for', 'you', '[Bridge]', 'In', 'mind', 'you', 'make', 'me', 'want', 'to', 'do', 'things,', 'love', 'you', 'Like', "I'm", 'supposed', 'to', 'You', 'make', 'me', 'want', 'to', 'love', 'you', 'Like', "I'm", 'supposed', 'to', 'You', 'make', 'me', 'want', 'to', 'love', 'you', 'Like', "I'm", 'supposed', 'to,', 'remind', 'you', 'Ayy', '[Chorus]', 'I', 'know', "you're", 'scared', 'of', 'dating,', 'falling', 'for', 'me', 'Shorty,', 'by', 'now', 'you', 'know', 'me', 'Right', 'here', 'for', 'you', 'always', 'You', 'know,', 'I', "don't", 'ever', 'change', 'Right', 'here', 'for', 'you', 'always', 'You', 'know', 'I', "don't", 'ever', 'change', 'Right', 'here', 'for', 'you']
# ['me', 'me', 'me', 'me', 'me', 'me', 'me', 'me', 'me', 'me', 'me', 'me']

# %%
six_count = []
for i in range(len(df)):
    if isinstance(df.loc[i, "lyrics"], str):
        count = len(re.findall("six", df.loc[i, "lyrics"]))
        count += len(re.findall("6", df.loc[i, "lyrics"]))
        six_count.append(count)
    else:
        six_count.append(np.nan)

df['six_count'] = six_count
df.sort_values(by=['six_count'], na_position='last', ascending=False)
# Out:
#                                     album  \
# 118  If You’re Reading This It’s Too Late
# 115  If You’re Reading This It’s Too Late
# 21                   Dark Lane Demo Tapes
# 233                       Comeback Season
# 20                   Dark Lane Demo Tapes
# ..                                    ...
# 127  If You’re Reading This It’s Too Late
# 128  If You’re Reading This It’s Too Late
# 289                      Unreleased Songs
# 184                        Thank Me Later
# 263                      Unreleased Songs
#
#                                           lyrics_title  \
# 118                                       6 God Lyrics
# 115                               Know Yourself Lyrics
# 21       Demons (Ft. Fivio Foreign & Sosa Geek) Lyrics
# 233             New Shit (Ft. Phonte & Von Pea) Lyrics
# 20                       From Florida With Love Lyrics
# ..                                                 ...
# 127                                      Jungle Lyrics
# 128                             6PM in New York Lyrics
# 289          Real Bad Karma (Ft. Bryson Tiller) Lyrics
# 184                    Thank Me Later [Booklet] Lyrics
# 263  Untitled DaBaby Collaboration* (Ft. DaBaby) Ly...
#
#                                             lyrics_url  \
# 118              https://genius.com/Drake-6-god-lyrics
# 115      https://genius.com/Drake-know-yourself-lyrics
# 21              https://genius.com/Drake-demons-lyrics
# 233           https://genius.com/Drake-new-shit-lyrics
# 20   https://genius.com/Drake-from-florida-with-lov...
# ..                                                 ...
# 127             https://genius.com/Drake-jungle-lyrics
# 128    https://genius.com/Drake-6pm-in-new-york-lyrics
# 289     https://genius.com/Drake-real-bad-karma-lyrics
# 184  https://genius.com/Drake-thank-me-later-bookle...
# 263  https://genius.com/Drake-untitled-dababy-colla...
#
#                                                 lyrics   track_views  \
# 118  [Produced by Boi-1da and SykSense]\n\n[Intro]\...          1.5M
# 115  [Part 1]\n\n[Intro]\nHol' it yute, hol' it, ho...            5M
# 21   [Intro: Drake & Fivio Foreign]\nLike what?\n(W...          258K
# 233  [Verse 1: Drake]\nCheck (Nottz, Nottz, Nottz)\...          9.9K
# 20   [Intro]\n(Plugg)\n(Bitch)\nAyy, yeah\n\n[Verse...        222.3K
# ..                                                 ...           ...
# 127  [Chorus: Gabriel Garzón Montano]\nRock me real...          2.5M
# 128  [Intro]\nYeah\nYeah\n\n[Verse]\nOh, you gotta ...          1.1M
# 289  [Intro: Drake]\n(Sonorous on the beat)\nAnd I ...         50.6K
# 184                                                NaN          6.2K
# 263                                                NaN  (Unreleased)
#
#      six_count
# 118        8.0
# 115        8.0
# 21         5.0
# 233        4.0
# 20         4.0
# ..         ...
# 127        0.0
# 128        0.0
# 289        0.0
# 184        NaN
# 263        NaN
#
# [290 rows x 6 columns]

# %%
fuck_count = []
for i in range(len(df)):
    if isinstance(df.loc[i, "lyrics"], str):
        count = len(re.findall("fuck", df.loc[i, "lyrics"]))
        fuck_count.append(count)
    else:
        fuck_count.append(np.nan)

df['fuck_count'] = fuck_count
df.sort_values(by=['fuck_count'], na_position='last', ascending=False)
# Out:
#                     album                                       lyrics_title  \
# 259      Unreleased Songs  Fuckin' Problems (Lost Verse) by Kendrick Lama...
# 23           Care Package                        Dreams Money Can Buy Lyrics
# 136  Nothing Was the Same                              Worst Behavior Lyrics
# 187      So Far Gone (EP)                             Best I Ever Had Lyrics
# 201           So Far Gone                             Best I Ever Had Lyrics
# ..                    ...                                                ...
# 63               Scorpion  Don't Matter to Me by Drake & Michael Jackson ...
# 58               Scorpion                                     Finesse Lyrics
# 0     Certified Lover Boy                        Certified Lover Boy* Lyrics
# 184        Thank Me Later                    Thank Me Later [Booklet] Lyrics
# 263      Unreleased Songs  Untitled DaBaby Collaboration* (Ft. DaBaby) Ly...
#
#                                             lyrics_url  \
# 259  https://genius.com/Kendrick-lamar-fuckin-probl...
# 23   https://genius.com/Drake-dreams-money-can-buy-...
# 136     https://genius.com/Drake-worst-behavior-lyrics
# 187    https://genius.com/Drake-best-i-ever-had-lyrics
# 201    https://genius.com/Drake-best-i-ever-had-lyrics
# ..                                                 ...
# 63   https://genius.com/Drake-and-michael-jackson-d...
# 58             https://genius.com/Drake-finesse-lyrics
# 0    https://genius.com/Drake-certified-lover-boy-l...
# 184  https://genius.com/Drake-thank-me-later-bookle...
# 263  https://genius.com/Drake-untitled-dababy-colla...
#
#                                                 lyrics   track_views  \
# 259  [Intro: Kendrick Lamar]\nI remember, being you...         17.4K
# 23   [Intro: Jai Paul]\nOoh-ooh-ooh, ooh-ooh-ooh-oo...        548.8K
# 136  [Produced by DJ Dahi]\n\n[Verse 1]\nWorst...\n...          2.3M
# 187  [Intro]\nYou know, a lot of girls be\nThinkin'...          1.3M
# 201  [Intro]\nYou know, a lot of girls be\nThinkin'...          1.3M
# ..                                                 ...           ...
# 63   [Verse 1: Drake]\nAyy, wild things you're doin...        914.8K
# 58   [Intro]\nYeah, turn everything up\nYeah, oh ye...        576.1K
# 0    [Verse]\nPut my feelings on ice\nAlways been a...          8.7K
# 184                                                NaN          6.2K
# 263                                                NaN  (Unreleased)
#
#      six_count  fuck_count
# 259        0.0        32.0
# 23         1.0        30.0
# 136        0.0        21.0
# 187        0.0        19.0
# 201        0.0        19.0
# ..         ...         ...
# 63         0.0         0.0
# 58         0.0         0.0
# 0          0.0         0.0
# 184        NaN         NaN
# 263        NaN         NaN
#
# [290 rows x 7 columns]

# %%
b_count = []
for i in range(len(df)):
    if isinstance(df.loc[i, "lyrics"], str):
        count = len(re.findall("bitch", df.loc[i, "lyrics"]))
        b_count.append(count)
    else:
        b_count.append(np.nan)

df['b_count'] = b_count
df.sort_values(by=['b_count'], na_position='last', ascending=False)
# Out:
#                                     album  \
# 259                      Unreleased Songs
# 174                        Thank Me Later
# 2                     Certified Lover Boy
# 168                             Take Care
# 21                   Dark Lane Demo Tapes
# ..                                    ...
# 115  If You’re Reading This It’s Too Late
# 117  If You’re Reading This It’s Too Late
# 289                      Unreleased Songs
# 184                        Thank Me Later
# 263                      Unreleased Songs
#
#                                           lyrics_title  \
# 259  Fuckin' Problems (Lost Verse) by Kendrick Lama...
# 174              Up All Night (Ft. Nicki Minaj) Lyrics
# 2                                    Not Around Lyrics
# 168    The Motto (Remix) (Ft. Lil Wayne & Tyga) Lyrics
# 21       Demons (Ft. Fivio Foreign & Sosa Geek) Lyrics
# ..                                                 ...
# 115                               Know Yourself Lyrics
# 117                                     Madonna Lyrics
# 289          Real Bad Karma (Ft. Bryson Tiller) Lyrics
# 184                    Thank Me Later [Booklet] Lyrics
# 263  Untitled DaBaby Collaboration* (Ft. DaBaby) Ly...
#
#                                             lyrics_url  \
# 259  https://genius.com/Kendrick-lamar-fuckin-probl...
# 174       https://genius.com/Drake-up-all-night-lyrics
# 2           https://genius.com/Drake-not-around-lyrics
# 168    https://genius.com/Drake-the-motto-remix-lyrics
# 21              https://genius.com/Drake-demons-lyrics
# ..                                                 ...
# 115      https://genius.com/Drake-know-yourself-lyrics
# 117            https://genius.com/Drake-madonna-lyrics
# 289     https://genius.com/Drake-real-bad-karma-lyrics
# 184  https://genius.com/Drake-thank-me-later-bookle...
# 263  https://genius.com/Drake-untitled-dababy-colla...
#
#                                                 lyrics   track_views  \
# 259  [Intro: Kendrick Lamar]\nI remember, being you...         17.4K
# 174  [Verse 1: Drake]\nKush rolled, glass full: I p...        489.2K
# 2    [Intro]\nYeah, we back\nWassup ladies?\nSwisha...        129.8K
# 168  [Produced by T-Minus]\n\n[Verse 1: Drake]\nI'm...        336.1K
# 21   [Intro: Drake & Fivio Foreign]\nLike what?\n(W...          258K
# ..                                                 ...           ...
# 115  [Part 1]\n\n[Intro]\nHol' it yute, hol' it, ho...            5M
# 117  [Produced by Noah "40" Shebib]\n\n[Chorus]\nBr...        794.7K
# 289  [Intro: Drake]\n(Sonorous on the beat)\nAnd I ...         50.6K
# 184                                                NaN          6.2K
# 263                                                NaN  (Unreleased)
#
#      six_count  fuck_count  b_count
# 259        0.0        32.0     10.0
# 174        2.0         4.0      8.0
# 2          0.0         0.0      7.0
# 168        0.0         8.0      7.0
# 21         5.0         1.0      7.0
# ..         ...         ...      ...
# 115        8.0         1.0      0.0
# 117        2.0         0.0      0.0
# 289        0.0         1.0      0.0
# 184        NaN         NaN      NaN
# 263        NaN         NaN      NaN
#
# [290 rows x 8 columns]

# %% [markdown]
# # Explore Track Views

# %%
df = df.drop(df.index[df['track_views'] == "(Unreleased)"].tolist())
df.drop_duplicates(subset ="lyrics_title", keep = 'first', inplace = True) 

df.track_views = (df.track_views.replace(r'[KM]+$', '', regex=True).astype(float) * df.track_views.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
# Binary Encoding

dummies = df.lyrics.str.get_dummies(sep=' ')
dummies = dummies.loc[:,dummies.sum() > 5]

# Clean binary encoding
remove = [col for col in dummies.columns if "\n" in col]
clean_names = [song for song in dummies.columns.tolist() if song not in remove]
dummies = dummies.loc[:,clean_names]

# %%
from sklearn.feature_extraction.text import CountVectorizer
df = df.dropna()
countvec = CountVectorizer(token_pattern=r"(?u)\b[a-zA-Z0-9_']+\b")
counts = countvec.fit_transform(df['lyrics'].tolist())
dummy_all = pd.DataFrame(counts.toarray(), columns=countvec.get_feature_names())


# Clean Counts
dummy = dummy_all.loc[:,dummy_all[dummy_all > 0].count() > 2]
remove = [col for col in dummy.columns if "\n" in col]
clean_names = [word for word in dummy.columns.tolist() if word not in remove]
labels = ["verse", "intro", "chorus", "outro", "\n"]
clean_names = [word for word in clean_names if word not in labels]
dummy = dummy.loc[:,clean_names]

# %%
import numpy as np
s_corr = dummy.corrwith(np.log(df.track_views))
s_corr.max()
s_corr.sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt
top_ten = s_corr.sort_values(ascending=False)[0:10]
bottom_ten = s_corr.sort_values(ascending=True)[0:10]

# %%
plt.hist(np.log(df.track_views))

# %%
top_ten.plot.bar(x='Word', y='Correlation to Views')

# %%
df.loc[(dummy_all["produced"] > 0).values,:]
